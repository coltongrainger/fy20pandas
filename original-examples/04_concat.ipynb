# %% [markdown]
# # Concat

# %%
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(12,6)})
plt.style.use(['seaborn-whitegrid'])

import warnings
warnings.simplefilter('ignore')

import os
import utils

# %% [markdown]
# Our `read_csv` function.

# %% [markdown]
# ```python
#     import pandas as pd
#
#     def read_csv(filename):
#         df = pd.read_csv(filename, skiprows=8)
#         df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
#         df['timestamp'] = pd.to_datetime(df['timestamp'])  #might not want this here
#         df.set_index('timestamp', inplace=True)
#         return df
# ```

# %%
filenames = ['data/measured_real_power.csv',
             'data/measured_reactive_power.csv']

# %% [markdown]
# Concat

# %%
df1 = utils.read_csv(filenames[0])
df2 = utils.read_csv(filenames[1])

df = pd.concat([df1, df2], axis=1) # stack side by side

# %%
df1.shape, df2.shape, df.shape
# Out:
# ((12961, 20), (12961, 20), (12961, 40))

# %%
len(set(df.columns))
# Out:
# 20

# %%
all(df1.columns == df2.columns)
# Out:
# True

# %% [markdown]
# So now we need to capture some additional information, the **prefix**

# %%
def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df.timestamp = pd.to_datetime(df.timestamp)
    df.set_index('timestamp', inplace=True)
    prefix = os.path.basename(filename).replace('.csv','')
    df.columns = [ "{}:{}".format(prefix, x) for x in df.columns ]
    return df

df = pd.concat([ read_csv(x) for x in filenames ], axis=1)
len(set(df.columns))
# Out:
# 40

# %%
df.columns
# Out:
# Index(['measured_real_power:triplex_meter_0',
#        'measured_real_power:triplex_meter_1',
#        'measured_real_power:triplex_meter_2',
#        'measured_real_power:triplex_meter_3',
#        'measured_real_power:triplex_meter_4',
#        'measured_real_power:triplex_meter_5',
#        'measured_real_power:triplex_meter_6',
#        'measured_real_power:triplex_meter_7',
#        'measured_real_power:triplex_meter_8',
#        'measured_real_power:triplex_meter_9',
#        'measured_real_power:triplex_meter_10',
#        'measured_real_power:triplex_meter_11',
#        'measured_real_power:triplex_meter_12',
#        'measured_real_power:triplex_meter_13',
#        'measured_real_power:triplex_meter_14',
#        'measured_real_power:triplex_meter_15',
#        'measured_real_power:triplex_meter_16',
#        'measured_real_power:triplex_meter_17',
#        'measured_real_power:triplex_meter_18',
#        'measured_real_power:triplex_meter_19',
#        'measured_reactive_power:triplex_meter_0',
#        'measured_reactive_power:triplex_meter_1',
#        'measured_reactive_power:triplex_meter_2',
#        'measured_reactive_power:triplex_meter_3',
#        'measured_reactive_power:triplex_meter_4',
#        'measured_reactive_power:triplex_meter_5',
#        'measured_reactive_power:triplex_meter_6',
#        'measured_reactive_power:triplex_meter_7',
#        'measured_reactive_power:triplex_meter_8',
#        'measured_reactive_power:triplex_meter_9',
#        'measured_reactive_power:triplex_meter_10',
#        'measured_reactive_power:triplex_meter_11',
#        'measured_reactive_power:triplex_meter_12',
#        'measured_reactive_power:triplex_meter_13',
#        'measured_reactive_power:triplex_meter_14',
#        'measured_reactive_power:triplex_meter_15',
#        'measured_reactive_power:triplex_meter_16',
#        'measured_reactive_power:triplex_meter_17',
#        'measured_reactive_power:triplex_meter_18',
#        'measured_reactive_power:triplex_meter_19'],
#       dtype='object')

# %% [markdown]
# ## Glob

# %%
import glob

# %% [markdown]
# Create some additional files for scaling demonstration

# %%
import os
import shutil

if os.path.exists("data/outputFiles"):
    shutil.rmtree("data/outputFiles")
os.mkdir("data/outputFiles")

for i in range(10):
    shutil.copyfile("data/measured_reactive_power.csv", 
                    "data/outputFiles/measured_reactive_power_{}.csv".format(i))
    shutil.copyfile("data/measured_real_power.csv", 
                    "data/outputFiles/measured_real_power_{}.csv".format(i))

# %%
filenames = glob.glob('data/outputFiles/*.csv')
filenames
# Out:
# ['data/outputFiles/measured_real_power_1.csv',
#  'data/outputFiles/measured_reactive_power_3.csv',
#  'data/outputFiles/measured_real_power_0.csv',
#  'data/outputFiles/measured_reactive_power_2.csv',
#  'data/outputFiles/measured_real_power_5.csv',
#  'data/outputFiles/measured_reactive_power_8.csv',
#  'data/outputFiles/measured_reactive_power_4.csv',
#  'data/outputFiles/measured_real_power_3.csv',
#  'data/outputFiles/measured_real_power_9.csv',
#  'data/outputFiles/measured_reactive_power_6.csv',
#  'data/outputFiles/measured_real_power_2.csv',
#  'data/outputFiles/measured_reactive_power_1.csv',
#  'data/outputFiles/measured_real_power_8.csv',
#  'data/outputFiles/measured_real_power_7.csv',
#  'data/outputFiles/measured_reactive_power_0.csv',
#  'data/outputFiles/measured_reactive_power_9.csv',
#  'data/outputFiles/measured_reactive_power_7.csv',
#  'data/outputFiles/measured_real_power_6.csv',
#  'data/outputFiles/measured_reactive_power_5.csv',
#  'data/outputFiles/measured_real_power_4.csv']

# %%
def read_dir(filenames):
    return pd.concat([ read_csv(x) for x in filenames ], axis=1)

read_dir(filenames).shape
# Out:
# (12961, 400)

# %% [markdown]
# Takes a while... Can we do better?

# %%
import cProfile

cProfile.run('read_dir(filenames)')
# Out:
#          98634130 function calls (98632544 primitive calls) in 68.110 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      1147    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:1009(_handle_fromlist)
#       320    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:103(release)
#       320    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:143(__init__)
#       320    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap>:147(__enter__)
#       320    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:151(__exit__)
#       320    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap>:157(_get_module_lock)
#       320    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:176(cb)
#   220/100    0.000    0.000    0.021    0.000 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#      2100    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:222(_verbose_message)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:369(__init__)
#       281    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:416(parent)
#       320    0.000    0.000    0.001    0.000 <frozen importlib._bootstrap>:58(__init__)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:719(find_spec)
#       320    0.001    0.000    0.001    0.000 <frozen importlib._bootstrap>:78(acquire)
#       100    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:792(find_spec)
#       500    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:855(__enter__)
#       500    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:859(__exit__)
#       200    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:873(_find_spec_legacy)
#       100    0.002    0.000    0.016    0.000 <frozen importlib._bootstrap>:882(_find_spec)
#   320/100    0.001    0.000    0.022    0.000 <frozen importlib._bootstrap>:948(_find_and_load_unlocked)
#   320/100    0.002    0.000    0.024    0.000 <frozen importlib._bootstrap>:978(_find_and_load)
#       460    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:1203(_path_importer_cache)
#       100    0.001    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:1240(_get_spec)
#       100    0.000    0.000    0.013    0.000 <frozen importlib._bootstrap_external>:1272(find_spec)
#       420    0.004    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1356(find_spec)
#       420    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap_external>:40(_relax_case)
#      2100    0.001    0.000    0.004    0.000 <frozen importlib._bootstrap_external>:56(_path_join)
#      2100    0.001    0.000    0.002    0.000 <frozen importlib._bootstrap_external>:58(<listcomp>)
#       420    0.000    0.000    0.003    0.000 <frozen importlib._bootstrap_external>:74(_path_stat)
#        20    0.004    0.000   68.085    3.404 <ipython-input-34-81cda3ebd4a7>:1(read_csv)
#        20    0.000    0.000    0.000    0.000 <ipython-input-34-81cda3ebd4a7>:7(<listcomp>)
#         1    0.000    0.000   68.108   68.108 <ipython-input-39-87837378269a>:1(read_dir)
#         1    0.000    0.000   68.085   68.085 <ipython-input-39-87837378269a>:2(<listcomp>)
#         1    0.003    0.003   68.110   68.110 <string>:1(<module>)
#        40    0.000    0.000    0.000    0.000 <string>:1(__new__)
#        20    0.000    0.000    0.000    0.000 __init__.py:124(lrange)
#       261    0.000    0.000    0.000    0.000 __init__.py:205(iteritems)
#        20    0.000    0.000    0.000    0.000 __init__.py:211(itervalues)
#        20    0.000    0.000    0.029    0.001 _decorators.py:185(wrapper)
#       781    0.002    0.000    0.005    0.000 _dtype.py:319(_name_get)
#       120    0.000    0.000    0.001    0.000 _dtype.py:46(__str__)
#    259220    0.087    0.000    0.087    0.000 _factories.py:9(__call__)
#       261    0.000    0.000    0.000    0.000 _internal.py:886(npy_ctypes_check)
#       101    0.000    0.000    0.001    0.000 _methods.py:42(_any)
#        40    0.000    0.000    0.000    0.000 _methods.py:45(_all)
#    518440    0.801    0.000    1.771    0.000 _parser.py:1008(_find_hms_idx)
#    777660    0.907    0.000    1.867    0.000 _parser.py:1058(_could_be_tzname)
#   1555320    0.468    0.000    0.468    0.000 _parser.py:1063(<genexpr>)
#    259220    0.483    0.000    0.483    0.000 _parser.py:1100(_parse_min_sec)
#    259220    0.213    0.000    0.213    0.000 _parser.py:1112(_parsems)
#    259220    0.597    0.000    1.281    0.000 _parser.py:1169(_build_tzaware)
#    259220    0.786    0.000    1.650    0.000 _parser.py:1209(_build_naive)
#    777660    1.036    0.000    1.169    0.000 _parser.py:1242(_to_decimal)
#    259220    0.521    0.000   48.638    0.000 _parser.py:1258(parse)
#    259220    0.041    0.000    0.041    0.000 _parser.py:192(__iter__)
#   3629080    1.397    0.000   16.262    0.000 _parser.py:195(__next__)
#    259220    1.297    0.000   18.467    0.000 _parser.py:205(split)
#   3888300    0.933    0.000    1.341    0.000 _parser.py:209(isword)
#   6739720    1.383    0.000    2.005    0.000 _parser.py:214(isnum)
#   1555320    0.337    0.000    0.518    0.000 _parser.py:219(isspace)
#    259220    0.622    0.000    1.077    0.000 _parser.py:227(__init__)
#    259220    0.275    0.000    2.088    0.000 _parser.py:239(__len__)
#   3369860    0.814    0.000    1.179    0.000 _parser.py:240(<genexpr>)
#    777660    0.391    0.000    0.492    0.000 _parser.py:325(jump)
#    777660    0.736    0.000    0.862    0.000 _parser.py:328(weekday)
#   1036880    0.800    0.000    0.923    0.000 _parser.py:335(month)
#    777660    0.807    0.000    0.922    0.000 _parser.py:342(hms)
#    777660    0.497    0.000    0.569    0.000 _parser.py:348(ampm)
#    259220    0.147    0.000    0.187    0.000 _parser.py:357(utczone)
#    259220    0.172    0.000    0.233    0.000 _parser.py:360(tzoffset)
#    259220    0.070    0.000    0.070    0.000 _parser.py:366(convertyear)
#    259220    0.389    0.000    0.646    0.000 _parser.py:386(validate)
#    259220    0.434    0.000    0.434    0.000 _parser.py:400(__init__)
#    259220    0.067    0.000    0.067    0.000 _parser.py:407(has_year)
#    777660    2.017    0.000    2.630    0.000 _parser.py:433(append)
#    259220    0.889    0.000    1.198    0.000 _parser.py:479(resolve_ymd)
#    259220    0.171    0.000    0.171    0.000 _parser.py:487(<dictcomp>)
#    259220    0.915    0.000   48.116    0.000 _parser.py:577(parse)
#    259220    0.770    0.000    0.867    0.000 _parser.py:62(__init__)
#    259220    5.389    0.000   41.949    0.000 _parser.py:668(_parse)
#   3629080    9.171    0.000   14.865    0.000 _parser.py:83(get_token)
#    518440    3.198    0.000   10.178    0.000 _parser.py:877(_parse_numeric_token)
#   1036880    0.596    0.000    4.264    0.000 _strptime.py:26(_getlang)
#   1036880    5.426    0.000   11.349    0.000 _strptime.py:318(_strptime)
#   1036880    0.564    0.000   11.913    0.000 _strptime.py:574(_strptime_datetime)
#        40    0.000    0.000    0.000    0.000 _validators.py:221(validate_bool_kwarg)
#        20    0.000    0.000    0.000    0.000 _validators.py:230(validate_axis_style_args)
#       239    0.000    0.000    0.000    0.000 abc.py:137(__instancecheck__)
#        20    0.000    0.000    0.001    0.000 algorithms.py:1421(_get_take_nd_function)
#        20    0.000    0.000    0.002    0.000 algorithms.py:1548(take_nd)
#         1    0.000    0.000    0.000    0.000 api.py:129(_sanitize_and_check)
#         1    0.000    0.000    0.000    0.000 api.py:130(<setcomp>)
#         1    0.000    0.000    0.002    0.002 api.py:47(_get_objs_combined_axis)
#         1    0.000    0.000    0.000    0.000 api.py:51(<listcomp>)
#         1    0.000    0.000    0.002    0.002 api.py:57(_get_combined_index)
#         1    0.000    0.000    0.002    0.002 api.py:80(_union_indexes)
#        20    0.000    0.000    0.000    0.000 base.py:104(_reset_cache)
#        19    0.000    0.000    0.000    0.000 base.py:1302(_assert_can_do_setop)
#         1    0.000    0.000    0.000    0.000 base.py:1500(is_monotonic_increasing)
#        21    0.000    0.000    0.000    0.000 base.py:1569(is_unique)
#        40    0.000    0.000    0.000    0.000 base.py:1590(is_object)
#        20    0.000    0.000    0.000    0.000 base.py:1928(_cleanup)
#        40    0.000    0.000    0.000    0.000 base.py:1935(_engine)
#        21    0.000    0.000    0.000    0.000 base.py:1938(<lambda>)
#        40    0.000    0.000    0.000    0.000 base.py:1976(is_all_dates)
#       140    0.001    0.000    0.001    0.000 base.py:2033(__contains__)
#        20    0.000    0.000    0.000    0.000 base.py:2053(contains)
#       480    0.001    0.000    0.001    0.000 base.py:2067(__getitem__)
#        40    0.000    0.000    0.001    0.000 base.py:2101(_can_hold_identifiers_and_holds_name)
#         1    0.000    0.000    0.001    0.001 base.py:2114(append)
#         1    0.000    0.000    0.000    0.000 base.py:2138(<setcomp>)
#         1    0.000    0.000    0.001    0.001 base.py:2143(_concat)
#         1    0.000    0.000    0.000    0.000 base.py:2151(_concat_same_dtype)
#        40    0.000    0.000    0.002    0.000 base.py:2445(equals)
#        20    0.000    0.000    0.001    0.000 base.py:2465(identical)
#        40    0.000    0.000    0.000    0.000 base.py:2470(<genexpr>)
#   201/141    0.003    0.000    0.016    0.000 base.py:255(__new__)
#        19    0.000    0.000    0.000    0.000 base.py:2708(_get_consensus_name)
#        19    0.000    0.000    0.001    0.000 base.py:2723(union)
#       120    0.000    0.000    0.001    0.000 base.py:3071(get_loc)
#        40    0.000    0.000    0.000    0.000 base.py:444(<genexpr>)
#       161    0.001    0.000    0.001    0.000 base.py:473(_simple_new)
#        20    0.000    0.000    0.002    0.000 base.py:4874(_ensure_index_from_sequences)
#       382    0.001    0.000    0.027    0.000 base.py:4914(_ensure_index)
#        40    0.000    0.000    0.001    0.000 base.py:510(_shallow_copy)
#         1    0.000    0.000    0.000    0.000 base.py:520(_shallow_copy_with_infer)
#        40    0.000    0.000    0.000    0.000 base.py:547(_deepcopy_if_needed)
#      2123    0.002    0.000    0.003    0.000 base.py:61(is_dtype)
#        79    0.000    0.000    0.000    0.000 base.py:615(is_)
#       241    0.000    0.000    0.000    0.000 base.py:635(_reset_identity)
#       707    0.000    0.000    0.000    0.000 base.py:641(__len__)
#         1    0.000    0.000    0.000    0.000 base.py:647(__array__)
#       100    0.000    0.000    0.000    0.000 base.py:662(dtype)
#       421    0.000    0.000    0.001    0.000 base.py:672(values)
#       160    0.000    0.000    0.000    0.000 base.py:677(_values)
#        80    0.000    0.000    0.000    0.000 base.py:711(get_values)
#        20    0.000    0.000    0.000    0.000 base.py:766(size)
#        22    0.000    0.000    0.000    0.000 base.py:789(_ndarray_values)
#        21    0.000    0.000    0.000    0.000 base.py:803(empty)
#        60    0.000    0.000    0.002    0.000 base.py:893(tolist)
#        60    0.000    0.000    0.003    0.000 base.py:912(__iter__)
#        42    0.000    0.000    0.000    0.000 base.py:920(_get_attributes_dict)
#        42    0.000    0.000    0.000    0.000 base.py:922(<dictcomp>)
#        40    0.000    0.000    0.001    0.000 base.py:924(view)
#       120    0.001    0.000    0.002    0.000 cast.py:1207(construct_1d_object_array_from_listlike)
#        40    0.000    0.000    0.000    0.000 cast.py:1232(construct_1d_ndarray_preserving_na)
#       460    0.001    0.000    0.004    0.000 cast.py:853(maybe_castable)
#        40    0.000    0.000    0.001    0.000 cast.py:867(maybe_infer_to_datetimelike)
#        80    0.000    0.000    0.002    0.000 cast.py:971(maybe_cast_to_datetime)
#        20    0.000    0.000    0.000    0.000 common.py:100(is_bool_indexer)
#       141    0.000    0.000    0.001    0.000 common.py:1043(is_datetime64_any_dtype)
#        40    0.000    0.000    0.000    0.000 common.py:1083(is_datetime64_ns_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:113(_validate_header_arg)
#        40    0.000    0.000    0.000    0.000 common.py:1170(is_datetime_or_timedelta_dtype)
#        40    0.000    0.000    0.013    0.000 common.py:121(_stringify_path)
#       720    0.000    0.000    0.002    0.000 common.py:122(is_sparse)
#        20    0.000    0.000    0.000    0.000 common.py:1405(needs_i8_conversion)
#         1    0.000    0.000    0.000    0.000 common.py:141(_not_none)
#        21    0.000    0.000    0.000    0.000 common.py:143(<genexpr>)
#        20    0.000    0.000    0.000    0.000 common.py:1490(is_string_like_dtype)
#       581    0.001    0.000    0.001    0.000 common.py:1527(is_float_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:154(_all_none)
#       181    0.000    0.000    0.001    0.000 common.py:1578(is_bool_dtype)
#        80    0.000    0.000    0.001    0.000 common.py:1629(is_extension_type)
#        20    0.000    0.000    0.000    0.000 common.py:164(is_s3_url)
#       282    0.001    0.000    0.002    0.000 common.py:1688(is_extension_array_dtype)
#        20    0.000    0.000    0.007    0.000 common.py:172(get_filepath_or_buffer)
#        20    0.000    0.000    0.000    0.000 common.py:178(_count_not_none)
#       216    0.000    0.000    0.000    0.000 common.py:1784(_get_dtype)
#        60    0.000    0.000    0.000    0.000 common.py:180(<genexpr>)
#      2866    0.003    0.000    0.005    0.000 common.py:1835(_get_dtype_type)
#       140    0.000    0.000    0.001    0.000 common.py:195(is_categorical)
#        60    0.000    0.000    0.000    0.000 common.py:1965(pandas_dtype)
#       300    0.000    0.000    0.001    0.000 common.py:227(is_datetimetz)
#        20    0.000    0.000    0.007    0.000 common.py:246(_infer_compression)
#       181    0.001    0.000    0.003    0.000 common.py:301(_asarray_tuplesafe)
#       401    0.000    0.000    0.001    0.000 common.py:332(is_datetime64_dtype)
#       561    0.000    0.000    0.001    0.000 common.py:369(is_datetime64tz_dtype)
#        80    0.000    0.000    0.000    0.000 common.py:395(_apply_if_callable)
#       241    0.000    0.000    0.001    0.000 common.py:407(is_timedelta64_dtype)
#        80    0.000    0.000    0.000    0.000 common.py:444(is_period_dtype)
#       462    0.000    0.000    0.002    0.000 common.py:477(is_interval_dtype)
#      1422    0.001    0.000    0.002    0.000 common.py:513(is_categorical_dtype)
#        80    0.000    0.000    0.001    0.000 common.py:546(is_string_dtype)
#         1    0.000    0.000    0.000    0.000 common.py:585(is_period_arraylike)
#         1    0.000    0.000    0.000    0.000 common.py:586(_get_distinct_objs)
#        60    0.000    0.000    0.001    0.000 common.py:647(is_datetimelike)
#        38    0.000    0.000    0.000    0.000 common.py:692(is_dtype_equal)
#        20    0.000    0.000    0.001    0.000 common.py:77(_is_url)
#       900    0.003    0.000    0.005    0.000 common.py:811(is_integer_dtype)
#       121    0.000    0.000    0.000    0.000 common.py:858(is_signed_integer_dtype)
#       300    0.000    0.000    0.001    0.000 common.py:89(is_object_dtype)
#       121    0.000    0.000    0.000    0.000 common.py:907(is_unsigned_integer_dtype)
#        20    0.000    0.000    0.000    0.000 common.py:95(_expand_user)
#        20    0.000    0.000    0.000    0.000 common.py:995(is_int_or_datetime_dtype)
#         2    0.000    0.000    0.000    0.000 concat.py:101(<genexpr>)
#        40    0.000    0.000    0.000    0.000 concat.py:105(_get_sliced_frame_result_type)
#         1    0.000    0.000    0.022    0.022 concat.py:21(concat)
#         1    0.000    0.000    0.003    0.003 concat.py:234(__init__)
#         1    0.000    0.000    0.000    0.000 concat.py:26(get_dtype_kinds)
#         1    0.000    0.000    0.000    0.000 concat.py:306(<listcomp>)
#         1    0.000    0.000    0.019    0.019 concat.py:380(get_result)
#         1    0.000    0.000    0.000    0.000 concat.py:431(_get_result_dim)
#         1    0.000    0.000    0.003    0.003 concat.py:437(_get_new_axes)
#         1    0.000    0.000    0.002    0.002 concat.py:461(_get_comb_axis)
#         1    0.000    0.000    0.001    0.001 concat.py:472(_get_concat_axis)
#         1    0.000    0.000    0.000    0.000 concat.py:504(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:515(_concat_index_asobject)
#         1    0.000    0.000    0.000    0.000 concat.py:520(_maybe_check_integrity)
#         1    0.000    0.000    0.000    0.000 concat.py:525(<listcomp>)
#         1    0.000    0.000    0.001    0.001 concat.py:528(_concat_indexes)
#         1    0.000    0.000    0.000    0.000 concat.py:532(<listcomp>)
#         1    0.000    0.000    0.000    0.000 concat.py:90(_get_frame_result_type)
#         2    0.000    0.000    0.000    0.000 concat.py:97(<genexpr>)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:208(_validate_frequency)
#        20    0.000    0.000    0.000    0.000 datetimelike.py:232(freq)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:237(freq)
#        39    0.000    0.000    0.002    0.000 datetimelike.py:249(equals)
#         1    0.000    0.000    0.000    0.000 datetimelike.py:447(inferred_freq)
#        20    0.000    0.000   66.780    3.339 datetimes.py:106(to_datetime)
#         1    0.000    0.000    0.002    0.002 datetimes.py:1209(union_many)
#        19    0.000    0.000    0.000    0.000 datetimes.py:1257(_maybe_utc_convert)
#        19    0.000    0.000    0.000    0.000 datetimes.py:1285(_can_fast_union)
#         1    0.000    0.000    0.000    0.000 datetimes.py:2119(inferred_type)
#        20    0.000    0.000    0.000    0.000 datetimes.py:2125(dtype)
#        20    0.000    0.000   66.770    3.339 datetimes.py:276(_convert_listlike)
#        40    0.000    0.000    0.002    0.000 datetimes.py:329(__new__)
#        20    0.000    0.000    0.006    0.000 datetimes.py:39(_maybe_cache)
#        40    0.000    0.000    0.001    0.000 datetimes.py:627(_simple_new)
#        22    0.000    0.000    0.000    0.000 datetimes.py:675(_values)
#       139    0.000    0.000    0.000    0.000 datetimes.py:684(tz)
#         1    0.000    0.000    0.000    0.000 datetimes.py:702(size)
#        80    0.000    0.000    0.000    0.000 dtypes.py:266(construct_from_string)
#        20    0.000    0.000    0.000    0.000 dtypes.py:401(__new__)
#        20    0.000    0.000    0.000    0.000 dtypes.py:459(construct_from_string)
#        80    0.000    0.000    0.000    0.000 dtypes.py:584(is_dtype)
#        60    0.000    0.000    0.000    0.000 dtypes.py:675(construct_from_string)
#       261    0.001    0.000    0.001    0.000 dtypes.py:707(is_dtype)
#        60    0.000    0.000    0.005    0.000 frame.py:2664(__getitem__)
#        60    0.000    0.000    0.004    0.000 frame.py:2690(_getitem_column)
#        40    0.000    0.000    0.002    0.000 frame.py:3093(_box_item_values)
#        40    0.000    0.000    0.001    0.000 frame.py:3100(_box_col_values)
#        20    0.000    0.000    0.008    0.000 frame.py:3105(__setitem__)
#        20    0.000    0.000    0.000    0.000 frame.py:3165(_ensure_valid_index)
#        20    0.000    0.000    0.008    0.000 frame.py:3182(_set_item)
#        20    0.000    0.000    0.001    0.000 frame.py:3324(_sanitize_column)
#        21    0.000    0.000    0.069    0.003 frame.py:334(__init__)
#        20    0.000    0.000    0.000    0.000 frame.py:3344(reindexer)
#        20    0.000    0.000    0.029    0.001 frame.py:3699(rename)
#        20    0.000    0.000    0.011    0.001 frame.py:3805(set_index)
#        20    0.000    0.000    0.068    0.003 frame.py:426(_init_dict)
#        20    0.000    0.000    0.000    0.000 frame.py:555(shape)
#        20    0.000    0.000    0.044    0.002 frame.py:7349(_arrays_to_mgr)
#        20    0.001    0.000    0.008    0.000 frame.py:7644(_homogenize)
#        20    0.000    0.000    0.000    0.000 frame.py:844(__len__)
#         1    0.000    0.000    0.000    0.000 frequencies.py:184(get_offset)
#         1    0.000    0.000    0.000    0.000 frequencies.py:221(infer_freq)
#        42    0.000    0.000    0.000    0.000 frequencies.py:74(to_offset)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:2171(all)
#        40    0.000    0.000    0.000    0.000 fromnumeric.py:2847(ndim)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:69(_wrapreduction)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:70(<dictcomp>)
#        20    0.000    0.000    0.000    0.000 function.py:38(__call__)
#       181    0.000    0.000    0.000    0.000 generic.py:124(__init__)
#        40    0.000    0.000    0.000    0.000 generic.py:164(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 generic.py:178(_init_mgr)
#        60    0.000    0.000    0.004    0.000 generic.py:2484(_get_item_cache)
#        40    0.000    0.000    0.000    0.000 generic.py:2498(_set_as_cached)
#        20    0.000    0.000    0.000    0.000 generic.py:2543(_maybe_update_cacher)
#       100    0.000    0.000    0.000    0.000 generic.py:2577(_clear_item_cache)
#        20    0.000    0.000    0.006    0.000 generic.py:2599(_set_item)
#        40    0.000    0.000    0.000    0.000 generic.py:2633(_check_setitem_copy)
#        20    0.000    0.000    0.006    0.000 generic.py:2717(__delitem__)
#        40    0.000    0.000    0.000    0.000 generic.py:317(_construct_axes_from_arguments)
#        20    0.000    0.000    0.000    0.000 generic.py:3171(_update_inplace)
#        40    0.000    0.000    0.000    0.000 generic.py:349(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 generic.py:352(_from_axes)
#        42    0.000    0.000    0.000    0.000 generic.py:364(_get_axis_number)
#        20    0.000    0.000    0.002    0.000 generic.py:3647(reindex)
#        40    0.000    0.000    0.002    0.000 generic.py:3674(<genexpr>)
#        80    0.000    0.000    0.000    0.000 generic.py:377(_get_axis_name)
#        40    0.000    0.000    0.000    0.000 generic.py:390(_get_axis)
#        21    0.000    0.000    0.000    0.000 generic.py:394(_get_block_manager_axis)
#        21    0.000    0.000    0.000    0.000 generic.py:4345(__finalize__)
#   241/221    0.001    0.000    0.004    0.000 generic.py:4362(__getattr__)
#       400    0.002    0.000    0.019    0.000 generic.py:4378(__setattr__)
#        60    0.000    0.000    0.000    0.000 generic.py:438(_info_axis)
#        60    0.000    0.000    0.001    0.000 generic.py:4423(_protect_consolidate)
#        60    0.000    0.000    0.001    0.000 generic.py:4433(_consolidate_inplace)
#        60    0.000    0.000    0.001    0.000 generic.py:4436(f)
#        20    0.000    0.000    0.000    0.000 generic.py:4441(_consolidate)
#        22    0.000    0.000    0.000    0.000 generic.py:458(ndim)
#        20    0.000    0.000    0.003    0.000 generic.py:6224(isnull)
#        40    0.000    0.000    0.007    0.000 generic.py:645(_set_axis)
#      3863    0.002    0.000    0.002    0.000 generic.py:7(_check)
#        20    0.000    0.000    0.028    0.001 generic.py:926(rename)
#        20    0.000    0.000    0.000    0.000 generic.py:947(_get_rename_function)
#       420    0.000    0.000    0.000    0.000 generic.py:950(f)
#        20    0.000    0.000    0.003    0.000 generic.py:9675(logical_func)
#        20    0.000    0.000    0.001    0.000 index_tricks.py:316(__getitem__)
#        20    0.000    0.000    0.000    0.000 indexing.py:2321(convert_to_index_sliceable)
#       160    0.000    0.000    0.000    0.000 inference.py:119(is_iterator)
#        20    0.000    0.000    0.000    0.000 inference.py:158(is_file_like)
#       239    0.000    0.000    0.001    0.000 inference.py:251(is_list_like)
#        60    0.000    0.000    0.000    0.000 inference.py:415(is_hashable)
#       240    0.001    0.000    0.004    0.000 internals.py:116(__init__)
#       240    0.000    0.000    0.000    0.000 internals.py:127(_check_ndim)
#        20    0.000    0.000    0.000    0.000 internals.py:199(external_values)
#       180    0.000    0.000    0.000    0.000 internals.py:203(internal_values)
#        80    0.000    0.000    0.001    0.000 internals.py:2298(__init__)
#       600    0.000    0.000    0.000    0.000 internals.py:233(mgr_locs)
#       260    0.001    0.000    0.002    0.000 internals.py:237(mgr_locs)
#        20    0.000    0.000    0.000    0.000 internals.py:2413(should_store)
#        60    0.000    0.000    0.001    0.000 internals.py:2632(__init__)
#        60    0.000    0.000    0.000    0.000 internals.py:2637(_maybe_coerce_values)
#       100    0.000    0.000    0.002    0.000 internals.py:269(make_block_same_class)
#       560    0.001    0.000    0.004    0.000 internals.py:3148(get_block_type)
#       240    0.001    0.000    0.008    0.000 internals.py:3191(make_block)
#        41    0.000    0.000    0.008    0.000 internals.py:3265(__init__)
#        41    0.000    0.000    0.000    0.000 internals.py:3266(<listcomp>)
#       203    0.001    0.000    0.002    0.000 internals.py:3307(shape)
#       609    0.000    0.000    0.001    0.000 internals.py:3309(<genexpr>)
#       182    0.000    0.000    0.000    0.000 internals.py:3311(ndim)
#        60    0.000    0.000    0.007    0.000 internals.py:3315(set_axis)
#        20    0.000    0.000    0.025    0.001 internals.py:3327(rename_axis)
#        20    0.000    0.000    0.000    0.000 internals.py:3351(_is_single_block)
#        61    0.002    0.000    0.005    0.000 internals.py:3363(_rebuild_blknos_and_blklocs)
#       201    0.000    0.000    0.000    0.000 internals.py:3384(_get_items)
#        20    0.000    0.000    0.000    0.000 internals.py:3473(__len__)
#        60    0.000    0.000    0.000    0.000 internals.py:348(shape)
#        21    0.000    0.000    0.001    0.000 internals.py:3488(_verify_integrity)
#        81    0.000    0.000    0.000    0.000 internals.py:3490(<genexpr>)
#        20    0.000    0.000    0.019    0.001 internals.py:3500(apply)
#       120    0.000    0.000    0.000    0.000 internals.py:352(dtype)
#       120    0.000    0.000    0.003    0.000 internals.py:356(ftype)
#        20    0.000    0.000    0.000    0.000 internals.py:3561(<genexpr>)
#        40    0.000    0.000    0.000    0.000 internals.py:372(iget)
#       100    0.000    0.000    0.000    0.000 internals.py:3776(is_consolidated)
#        61    0.000    0.000    0.003    0.000 internals.py:3784(_consolidate_check)
#        61    0.000    0.000    0.003    0.000 internals.py:3785(<listcomp>)
#        60    0.000    0.000    0.000    0.000 internals.py:3891(nblocks)
#        20    0.000    0.000    0.020    0.001 internals.py:3895(copy)
#        40    0.000    0.000    0.001    0.000 internals.py:3915(<lambda>)
#        20    0.000    0.000    0.001    0.000 internals.py:3916(<listcomp>)
#        60    0.000    0.000    0.000    0.000 internals.py:4085(consolidate)
#        60    0.000    0.000    0.000    0.000 internals.py:4101(_consolidate_inplace)
#        40    0.000    0.000    0.002    0.000 internals.py:4108(get)
#        40    0.000    0.000    0.001    0.000 internals.py:4137(iget)
#        20    0.001    0.000    0.006    0.000 internals.py:4170(delete)
#        40    0.000    0.000    0.000    0.000 internals.py:4203(<genexpr>)
#        20    0.002    0.000    0.006    0.000 internals.py:4208(set)
#        20    0.000    0.000    0.000    0.000 internals.py:4235(value_getitem)
#        40    0.000    0.000    0.000    0.000 internals.py:4287(<genexpr>)
#       120    0.000    0.000    0.003    0.000 internals.py:4639(__init__)
#       200    0.000    0.000    0.000    0.000 internals.py:4684(_block)
#        20    0.000    0.000    0.000    0.000 internals.py:4742(external_values)
#       180    0.000    0.000    0.000    0.000 internals.py:4745(internal_values)
#        20    0.000    0.000    0.000    0.000 internals.py:4768(is_consolidated)
#        20    0.000    0.000    0.029    0.001 internals.py:4869(create_block_manager_from_arrays)
#        20    0.002    0.000    0.026    0.001 internals.py:4880(form_blocks)
#        20    0.000    0.000    0.004    0.000 internals.py:4972(_simple_blockify)
#        20    0.000    0.000    0.016    0.001 internals.py:4986(_multi_blockify)
#       400    0.000    0.000    0.000    0.000 internals.py:4990(<lambda>)
#        40    0.015    0.000    0.017    0.000 internals.py:5017(_stack_arrays)
#       420    0.000    0.000    0.001    0.000 internals.py:5020(_asarray_compat)
#        40    0.000    0.000    0.000    0.000 internals.py:5026(_shape_compat)
#        40    0.000    0.000    0.000    0.000 internals.py:5101(_extend_blocks)
#        40    0.000    0.000    0.000    0.000 internals.py:5208(_get_blkno_placements)
#        20    0.000    0.000    0.005    0.000 internals.py:5282(_transform_index)
#        20    0.000    0.000    0.000    0.000 internals.py:5298(<listcomp>)
#         1    0.000    0.000    0.018    0.018 internals.py:5388(concatenate_block_managers)
#         1    0.000    0.000    0.000    0.000 internals.py:5401(<listcomp>)
#        20    0.000    0.000    0.000    0.000 internals.py:5584(get_mgr_concatenation_plan)
#        21    0.000    0.000    0.000    0.000 internals.py:5663(combine_concat_plans)
#        20    0.000    0.000    0.000    0.000 internals.py:5757(__init__)
#        20    0.000    0.000    0.001    0.000 internals.py:5880(_fast_count_smallints)
#        40    0.000    0.000    0.015    0.000 internals.py:774(copy)
#   1036880    1.015    0.000    1.436    0.000 locale.py:384(normalize)
#   1036880    0.612    0.000    2.048    0.000 locale.py:467(_parse_localename)
#   1036880    0.681    0.000    3.668    0.000 locale.py:571(getlocale)
#        80    0.000    0.000    0.004    0.000 missing.py:112(_isna_new)
#        40    0.001    0.000    0.003    0.000 missing.py:189(_isna_ndarraylike)
#        80    0.000    0.000    0.004    0.000 missing.py:32(isna)
#        40    0.000    0.000    0.001    0.000 missing.py:376(array_equivalent)
#        20    0.000    0.000    0.000    0.000 missing.py:596(clean_reindex_fill_method)
#        20    0.000    0.000    0.000    0.000 missing.py:74(clean_fill_method)
#        20    0.000    0.000    0.000    0.000 nanops.py:179(_get_fill_value)
#        20    0.000    0.000    0.001    0.000 nanops.py:202(_get_values)
#        20    0.000    0.000    0.000    0.000 nanops.py:256(_na_ok_dtype)
#        20    0.000    0.000    0.000    0.000 nanops.py:260(_view_if_needed)
#        20    0.000    0.000    0.002    0.000 nanops.py:318(nanany)
#        60    0.000    0.000    0.000    0.000 numeric.py:110(is_all_dates)
#        77    0.000    0.000    0.000    0.000 numeric.py:174(asi8)
#         1    0.000    0.000    0.000    0.000 numeric.py:2431(isclose)
#         1    0.000    0.000    0.000    0.000 numeric.py:2508(within_tol)
#        38    0.001    0.000    0.001    0.000 numeric.py:2551(array_equal)
#        42    0.000    0.000    0.000    0.000 numeric.py:2656(seterr)
#        42    0.000    0.000    0.000    0.000 numeric.py:2758(geterr)
#        21    0.000    0.000    0.000    0.000 numeric.py:3054(__init__)
#        21    0.000    0.000    0.000    0.000 numeric.py:3058(__enter__)
#        21    0.000    0.000    0.000    0.000 numeric.py:3063(__exit__)
#       876    0.000    0.000    0.002    0.000 numeric.py:469(asarray)
#        22    0.000    0.000    0.000    0.000 numeric.py:541(asanyarray)
#        60    0.000    0.000    0.001    0.000 numeric.py:676(require)
#        60    0.000    0.000    0.000    0.000 numeric.py:748(<setcomp>)
#      1562    0.001    0.000    0.002    0.000 numerictypes.py:293(issubclass_)
#       781    0.001    0.000    0.003    0.000 numerictypes.py:365(issubdtype)
#        40    0.000    0.000    0.000    0.000 numerictypes.py:578(_can_coerce_all)
#       160    0.000    0.000    0.000    0.000 numerictypes.py:587(<listcomp>)
#        20    0.000    0.000    0.000    0.000 numerictypes.py:602(find_common_type)
#        20    0.000    0.000    0.000    0.000 numerictypes.py:654(<listcomp>)
#        20    0.000    0.000    0.000    0.000 numerictypes.py:655(<listcomp>)
#         2    0.000    0.000    0.000    0.000 offsets.py:2219(__init__)
#         1    0.000    0.000    0.000    0.000 offsets.py:394(rule_code)
#         1    0.000    0.000    0.000    0.000 offsets.py:398(freqstr)
#        80    0.000    0.000    0.000    0.000 parse.py:109(_coerce_args)
#        40    0.000    0.000    0.001    0.000 parse.py:361(urlparse)
#        15    0.000    0.000    0.000    0.000 parse.py:394(_checknetloc)
#        40    0.000    0.000    0.000    0.000 parse.py:409(urlsplit)
#        80    0.000    0.000    0.000    0.000 parse.py:98(_noop)
#        20    0.000    0.000    0.034    0.002 parsers.py:1012(_make_engine)
#        20    0.000    0.000    1.188    0.059 parsers.py:1029(read)
#        20    0.000    0.000    0.000    0.000 parsers.py:1059(_create_index)
#        60    0.000    0.000    0.000    0.000 parsers.py:1073(_is_index_col)
#        60    0.000    0.000    0.000    0.000 parsers.py:1077(_is_potential_multi_index)
#       120    0.000    0.000    0.000    0.000 parsers.py:1092(<genexpr>)
#        20    0.000    0.000    0.000    0.000 parsers.py:1171(_validate_usecols_arg)
#        20    0.000    0.000    0.000    0.000 parsers.py:1213(_validate_parse_dates_arg)
#        20    0.000    0.000    0.000    0.000 parsers.py:1236(__init__)
#        20    0.000    0.000    0.000    0.000 parsers.py:1306(_has_complex_date_col)
#        20    0.000    0.000    0.001    0.000 parsers.py:1386(_maybe_dedup_names)
#        40    0.000    0.000    0.000    0.000 parsers.py:1414(_maybe_make_multi_index_columns)
#        20    0.000    0.000    0.000    0.000 parsers.py:1420(_make_index)
#        20    0.000    0.000    0.000    0.000 parsers.py:1669(_do_date_conversions)
#        20    0.033    0.002    0.034    0.002 parsers.py:1685(__init__)
#        20    0.000    0.000    0.001    0.000 parsers.py:1779(close)
#        20    0.000    0.000    0.000    0.000 parsers.py:1789(_set_noconvert_columns)
#        20    0.000    0.000    1.118    0.056 parsers.py:1846(read)
#        20    0.000    0.000    0.000    0.000 parsers.py:1917(<listcomp>)
#        20    0.000    0.000    0.000    0.000 parsers.py:1919(<dictcomp>)
#        20    0.000    0.000    0.000    0.000 parsers.py:3000(_make_date_converter)
#        20    0.000    0.000    0.000    0.000 parsers.py:3038(_process_date_conversion)
#        20    0.000    0.000    0.000    0.000 parsers.py:3121(_clean_na_values)
#        40    0.000    0.000    0.000    0.000 parsers.py:358(_validate_integer)
#        20    0.000    0.000    0.000    0.000 parsers.py:388(_validate_names)
#        20    0.002    0.000    1.241    0.062 parsers.py:414(_read)
#        20    0.000    0.000    1.241    0.062 parsers.py:542(parser_f)
#        20    0.000    0.000    0.035    0.002 parsers.py:720(__init__)
#        20    0.000    0.000    0.001    0.000 parsers.py:789(close)
#        20    0.000    0.000    0.000    0.000 parsers.py:792(_get_options_with_defaults)
#        20    0.000    0.000    0.000    0.000 parsers.py:831(_check_file_or_buffer)
#        20    0.000    0.000    0.000    0.000 parsers.py:848(_clean_options)
#        20    0.000    0.000    0.000    0.000 posixpath.py:144(basename)
#        20    0.000    0.000    0.000    0.000 posixpath.py:232(expanduser)
#        20    0.000    0.000    0.000    0.000 posixpath.py:41(_get_sep)
#        40    0.000    0.000    0.000    0.000 range.py:131(_simple_new)
#        20    0.000    0.000    0.000    0.000 range.py:158(_validate_dtype)
#        20    0.000    0.000    0.000    0.000 range.py:177(_get_data_as_items)
#        20    0.000    0.000    0.000    0.000 range.py:260(_shallow_copy)
#        20    0.000    0.000    0.000    0.000 range.py:315(equals)
#       760    0.001    0.000    0.001    0.000 range.py:481(__len__)
#        40    0.000    0.000    0.001    0.000 range.py:68(__new__)
#        40    0.000    0.000    0.000    0.000 range.py:84(_ensure_int)
#         1    0.000    0.000    0.000    0.000 re.py:205(split)
#         1    0.000    0.000    0.000    0.000 re.py:271(_compile)
#   160/120    0.002    0.000    0.030    0.000 series.py:166(__init__)
#        40    0.000    0.000    0.015    0.000 series.py:284(_init_dict)
#        20    0.000    0.000    0.003    0.000 series.py:3203(_reduce)
#        20    0.000    0.000    0.002    0.000 series.py:3323(reindex)
#       160    0.000    0.000    0.001    0.000 series.py:365(_set_axis)
#        20    0.000    0.000    0.003    0.000 series.py:3802(isnull)
#       160    0.000    0.000    0.000    0.000 series.py:391(_set_subtyp)
#       220    0.000    0.000    0.001    0.000 series.py:401(name)
#       500    0.002    0.000    0.010    0.000 series.py:4019(_sanitize_array)
#       500    0.001    0.000    0.007    0.000 series.py:4036(_try_cast)
#       180    0.000    0.000    0.000    0.000 series.py:405(name)
#        20    0.000    0.000    0.000    0.000 series.py:432(values)
#       180    0.000    0.000    0.000    0.000 series.py:465(_values)
#        20    0.000    0.000    0.000    0.000 shape_base.py:83(atleast_2d)
#       200    0.000    0.000    0.000    0.000 six.py:184(find_module)
#       296    0.000    0.000    0.000    0.000 {built-in method __new__ of type object at 0x81f8a0}
#       239    0.000    0.000    0.000    0.000 {built-in method _abc._abc_instancecheck}
#      1140    0.000    0.000    0.000    0.000 {built-in method _imp.acquire_lock}
#        40    0.000    0.000    0.000    0.000 {built-in method _imp.is_builtin}
#       100    0.000    0.000    0.000    0.000 {built-in method _imp.is_frozen}
#      1140    0.000    0.000    0.000    0.000 {built-in method _imp.release_lock}
#   1036880    0.939    0.000    0.939    0.000 {built-in method _locale.setlocale}
#       640    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       640    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#   220/100    0.000    0.000    0.021    0.000 {built-in method builtins.__import__}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
# 518561/518541    0.416    0.000    0.822    0.000 {built-in method builtins.all}
#    259320    0.038    0.000    0.038    0.000 {built-in method builtins.callable}
#         1    0.000    0.000   68.110   68.110 {built-in method builtins.exec}
# 5191431/5191411    0.611    0.000    0.612    0.000 {built-in method builtins.getattr}
#    780715    0.221    0.000    0.221    0.000 {built-in method builtins.hasattr}
#       220    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        40    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#   2356353    0.297    0.000    0.300    0.000 {built-in method builtins.isinstance}
#      7691    0.002    0.000    0.002    0.000 {built-in method builtins.issubclass}
#       341    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
# 6745166/6744420    0.956    0.000    3.046    0.000 {built-in method builtins.len}
#       760    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#   3110640    0.455    0.000    0.455    0.000 {built-in method builtins.setattr}
#        20    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#    259281    0.634    0.000    1.813    0.000 {built-in method builtins.sum}
#       180    0.001    0.000    0.001    0.000 {built-in method numpy.arange}
#      1079    0.002    0.000    0.003    0.000 {built-in method numpy.array}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.bincount}
#        41    0.000    0.000    0.000    0.000 {built-in method numpy.concatenate}
#       342    0.003    0.000    0.003    0.000 {built-in method numpy.empty}
#        84    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        20    0.000    0.000    0.000    0.000 {built-in method numpy.putmask}
#         1    0.000    0.000    0.000    0.000 {built-in method numpy.result_type}
#        42    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        40    0.000    0.000    0.000    0.000 {built-in method numpy.zeros}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_int64}
#       160    0.000    0.000    0.000    0.000 {built-in method pandas._libs.algos.ensure_object}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.array_equivalent_object}
#        20    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.infer_datetimelike_array}
#        60    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_bool}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_datetime_array}
#       102    0.000    0.000    0.000    0.000 {built-in method pandas._libs.lib.is_integer}
#       700    0.001    0.000    0.001    0.000 {built-in method pandas._libs.lib.is_scalar}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#        20    6.218    0.311   66.769    3.338 {built-in method pandas._libs.tslib.array_to_datetime}
#        40    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.maybe_get_tz}
#        19    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.tz_compare}
#        59    0.000    0.000    0.000    0.000 {built-in method pandas._libs.tslibs.timezones.tz_standardize}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#        40    0.000    0.000    0.000    0.000 {built-in method posix.getcwd}
#       420    0.003    0.000    0.003    0.000 {built-in method posix.stat}
#        20    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#        40    0.001    0.000    0.001    0.000 {method 'add' of 'pandas._libs.internals.BlockPlacement' objects}
#        60    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         2    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.generic' objects}
#        38    0.000    0.000    0.000    0.000 {method 'all' of 'numpy.ndarray' objects}
#        81    0.000    0.000    0.001    0.000 {method 'any' of 'numpy.ndarray' objects}
#   2852620    0.536    0.000    0.536    0.000 {method 'append' of 'list' objects}
#        20    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#        20    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#       100    0.000    0.000    0.000    0.000 {method 'clear' of 'dict' objects}
#        20    0.000    0.000    0.000    0.000 {method 'clear_mapping' of 'pandas._libs.index.IndexEngine' objects}
#        20    0.001    0.000    0.001    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#        40    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       140    0.031    0.000    0.031    0.000 {method 'copy' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        20    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#    518440    0.063    0.000    0.063    0.000 {method 'end' of 're.Match' objects}
#        80    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       142    0.000    0.000    0.000    0.000 {method 'fill' of 'numpy.ndarray' objects}
#        15    0.000    0.000    0.000    0.000 {method 'find' of 'str' objects}
#       760    0.002    0.000    0.003    0.000 {method 'format' of 'str' objects}
#   2594425    0.518    0.000    0.518    0.000 {method 'get' of 'dict' objects}
#       120    0.000    0.000    0.000    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#    777660    0.133    0.000    0.133    0.000 {method 'is_finite' of 'decimal.Decimal' objects}
#   3888300    0.408    0.000    0.408    0.000 {method 'isalpha' of 'str' objects}
#   7776600    0.754    0.000    0.754    0.000 {method 'isdigit' of 'str' objects}
#   1555320    0.180    0.000    0.180    0.000 {method 'isspace' of 'str' objects}
#       364    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#      2100    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#   5443621    0.735    0.000    0.735    0.000 {method 'lower' of 'str' objects}
#   1036880    1.025    0.000    1.025    0.000 {method 'match' of 're.Pattern' objects}
#        60    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#       521    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#   1555340    0.446    0.000    0.446    0.000 {method 'pop' of 'list' objects}
#       100    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#   6221280    1.030    0.000    1.030    0.000 {method 'read' of '_io.StringIO' objects}
#        20    1.109    0.055    1.117    0.056 {method 'read' of 'pandas._libs.parsers.TextReader' objects}
#       141    0.001    0.000    0.001    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    518440    1.243    0.000    1.243    0.000 {method 'replace' of 'datetime.datetime' objects}
#        20    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {method 'rfind' of 'str' objects}
#      1021    0.000    0.000    0.000    0.000 {method 'rpartition' of 'str' objects}
#      4200    0.001    0.000    0.001    0.000 {method 'rstrip' of 'str' objects}
#        20    0.000    0.000    0.000    0.000 {method 'search' of 're.Pattern' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 're.Pattern' objects}
#        61    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#        60    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        40    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        61    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        61    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#        40    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#       499    0.001    0.000    0.001    0.000 {method 'view' of 'numpy.ndarray' objects}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_int64_int64}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_indexers}
#        80    0.002    0.000    0.016    0.000 {pandas._libs.lib.clean_index_list}
#       121    0.001    0.000    0.002    0.000 {pandas._libs.lib.infer_dtype}
#       120    0.000    0.000    0.000    0.000 {pandas._libs.lib.values_from_object}
#        20    0.000    0.000    0.000    0.000 {pandas._libs.missing.isnaobj}

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    #df.timestamp = pd.to_datetime(df.timestamp) #hold off for now...
    df.set_index('timestamp', inplace=True)
    prefix = os.path.basename(filename).replace('.csv','')
    df.columns = [ "{}:{}".format(prefix, x) for x in df.columns ] 
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=1, sort=False)
    df.index = pd.to_datetime(df.index)
    return df
# Out:
# Overwriting utils.py

# %%
# %load_ext autoreload
# %reload_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import utils

df = utils.read_dir(filenames)
df.shape
# Out:
# (12961, 400)

# %%
df.head()
# Out:
#                      measured_real_power_1:triplex_meter_0  \
# timestamp
# 2013-07-01 00:00:00                                510.912
# 2013-07-01 00:01:00                                510.912
# 2013-07-01 00:02:00                                510.912
# 2013-07-01 00:03:00                                510.912
# 2013-07-01 00:04:00                                510.911
#
#                      measured_real_power_1:triplex_meter_1  \
# timestamp
# 2013-07-01 00:00:00                                510.912
# 2013-07-01 00:01:00                                510.912
# 2013-07-01 00:02:00                                510.912
# 2013-07-01 00:03:00                                510.912
# 2013-07-01 00:04:00                                510.911
#
#                      measured_real_power_1:triplex_meter_2  \
# timestamp
# 2013-07-01 00:00:00                                510.912
# 2013-07-01 00:01:00                                510.912
# 2013-07-01 00:02:00                                510.912
# 2013-07-01 00:03:00                                510.912
# 2013-07-01 00:04:00                                510.911
#
#                      measured_real_power_1:triplex_meter_3  \
# timestamp
# 2013-07-01 00:00:00                                547.924
# 2013-07-01 00:01:00                                547.924
# 2013-07-01 00:02:00                                547.924
# 2013-07-01 00:03:00                                547.924
# 2013-07-01 00:04:00                                547.922
#
#                      measured_real_power_1:triplex_meter_4  \
# timestamp
# 2013-07-01 00:00:00                                510.912
# 2013-07-01 00:01:00                                510.912
# 2013-07-01 00:02:00                                510.912
# 2013-07-01 00:03:00                                510.912
# 2013-07-01 00:04:00                                510.911
#
#                      measured_real_power_1:triplex_meter_5  \
# timestamp
# 2013-07-01 00:00:00                                510.912
# 2013-07-01 00:01:00                                510.912
# 2013-07-01 00:02:00                                510.912
# 2013-07-01 00:03:00                                510.912
# 2013-07-01 00:04:00                                510.911
#
#                      measured_real_power_1:triplex_meter_6  \
# timestamp
# 2013-07-01 00:00:00                                547.924
# 2013-07-01 00:01:00                                547.924
# 2013-07-01 00:02:00                                547.924
# 2013-07-01 00:03:00                                547.924
# 2013-07-01 00:04:00                                547.922
#
#                      measured_real_power_1:triplex_meter_7  \
# timestamp
# 2013-07-01 00:00:00                                547.924
# 2013-07-01 00:01:00                                547.924
# 2013-07-01 00:02:00                                547.924
# 2013-07-01 00:03:00                                547.924
# 2013-07-01 00:04:00                                547.922
#
#                      measured_real_power_1:triplex_meter_8  \
# timestamp
# 2013-07-01 00:00:00                                581.637
# 2013-07-01 00:01:00                                581.637
# 2013-07-01 00:02:00                                581.637
# 2013-07-01 00:03:00                                581.637
# 2013-07-01 00:04:00                                581.645
#
#                      measured_real_power_1:triplex_meter_9  \
# timestamp
# 2013-07-01 00:00:00                                581.637
# 2013-07-01 00:01:00                                581.637
# 2013-07-01 00:02:00                                581.637
# 2013-07-01 00:03:00                                581.637
# 2013-07-01 00:04:00                                581.645
#
#                                       ...                    \
# timestamp                             ...
# 2013-07-01 00:00:00                   ...
# 2013-07-01 00:01:00                   ...
# 2013-07-01 00:02:00                   ...
# 2013-07-01 00:03:00                   ...
# 2013-07-01 00:04:00                   ...
#
#                      measured_real_power_4:triplex_meter_10  \
# timestamp
# 2013-07-01 00:00:00                                 384.146
# 2013-07-01 00:01:00                                 384.146
# 2013-07-01 00:02:00                                 384.146
# 2013-07-01 00:03:00                                 384.146
# 2013-07-01 00:04:00                                 384.151
#
#                      measured_real_power_4:triplex_meter_11  \
# timestamp
# 2013-07-01 00:00:00                                 384.146
# 2013-07-01 00:01:00                                 384.146
# 2013-07-01 00:02:00                                 384.146
# 2013-07-01 00:03:00                                 384.146
# 2013-07-01 00:04:00                                 384.151
#
#                      measured_real_power_4:triplex_meter_12  \
# timestamp
# 2013-07-01 00:00:00                                 384.146
# 2013-07-01 00:01:00                                 384.146
# 2013-07-01 00:02:00                                 384.146
# 2013-07-01 00:03:00                                 384.146
# 2013-07-01 00:04:00                                 384.151
#
#                      measured_real_power_4:triplex_meter_13  \
# timestamp
# 2013-07-01 00:00:00                                 531.494
# 2013-07-01 00:01:00                                 531.494
# 2013-07-01 00:02:00                                 531.494
# 2013-07-01 00:03:00                                 531.494
# 2013-07-01 00:04:00                                 384.151
#
#                      measured_real_power_4:triplex_meter_14  \
# timestamp
# 2013-07-01 00:00:00                                 531.494
# 2013-07-01 00:01:00                                 531.494
# 2013-07-01 00:02:00                                 531.494
# 2013-07-01 00:03:00                                 531.494
# 2013-07-01 00:04:00                                 531.501
#
#                      measured_real_power_4:triplex_meter_15  \
# timestamp
# 2013-07-01 00:00:00                                 531.494
# 2013-07-01 00:01:00                                 531.494
# 2013-07-01 00:02:00                                 531.494
# 2013-07-01 00:03:00                                 531.494
# 2013-07-01 00:04:00                                 531.501
#
#                      measured_real_power_4:triplex_meter_16  \
# timestamp
# 2013-07-01 00:00:00                                 530.845
# 2013-07-01 00:01:00                                 530.845
# 2013-07-01 00:02:00                                 530.845
# 2013-07-01 00:03:00                                 530.845
# 2013-07-01 00:04:00                                 530.849
#
#                      measured_real_power_4:triplex_meter_17  \
# timestamp
# 2013-07-01 00:00:00                                 530.845
# 2013-07-01 00:01:00                                 530.845
# 2013-07-01 00:02:00                                 530.845
# 2013-07-01 00:03:00                                 530.845
# 2013-07-01 00:04:00                                 530.849
#
#                      measured_real_power_4:triplex_meter_18  \
# timestamp
# 2013-07-01 00:00:00                                 271.123
# 2013-07-01 00:01:00                                 271.123
# 2013-07-01 00:02:00                                 271.123
# 2013-07-01 00:03:00                                 271.123
# 2013-07-01 00:04:00                                 271.125
#
#                      measured_real_power_4:triplex_meter_19
# timestamp
# 2013-07-01 00:00:00                                 383.677
# 2013-07-01 00:01:00                                 383.677
# 2013-07-01 00:02:00                                 383.677
# 2013-07-01 00:03:00                                 383.677
# 2013-07-01 00:04:00                                 383.680
#
# [5 rows x 400 columns]

# %% [markdown]
# ## The stacked method

# %%
filename = 'data/measured_real_power.csv'

df = pd.read_csv(filename, skiprows=8)
df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
df = df.melt(id_vars='timestamp')
df.head()
# Out:
#                  timestamp         variable    value
# 0  2013-07-01 00:00:00 UTC  triplex_meter_0  510.912
# 1  2013-07-01 00:01:00 UTC  triplex_meter_0  510.912
# 2  2013-07-01 00:02:00 UTC  triplex_meter_0  510.912
# 3  2013-07-01 00:03:00 UTC  triplex_meter_0  510.912
# 4  2013-07-01 00:04:00 UTC  triplex_meter_0  510.911

# %%
prefix = os.path.basename(filename).replace('.csv','')
df['attribute'] = prefix
df.head()
# Out:
#                  timestamp         variable    value            attribute
# 0  2013-07-01 00:00:00 UTC  triplex_meter_0  510.912  measured_real_power
# 1  2013-07-01 00:01:00 UTC  triplex_meter_0  510.912  measured_real_power
# 2  2013-07-01 00:02:00 UTC  triplex_meter_0  510.912  measured_real_power
# 3  2013-07-01 00:03:00 UTC  triplex_meter_0  510.912  measured_real_power
# 4  2013-07-01 00:04:00 UTC  triplex_meter_0  510.911  measured_real_power

# %% [markdown]
# We can stack this with concat

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df = df.melt(id_vars='timestamp')
    prefix = os.path.basename(filename).replace('.csv','')
    df['attribute'] = prefix
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=0, sort=False)  # axis = 0 for stacking
    #df.index = pd.to_datetime(df.index)
    return df
# Out:
# Overwriting utils.py

# %%
# %autoreload 2
import utils

df = utils.read_dir(filenames)
df.shape
# Out:
# (5184400, 4)

# %%
# takes a really long time....
#df.timestamp = pd.to_datetime(df.timestamp)

# %% [markdown]
# Reshaping can help...

# %%
tmp = df.pivot_table(index='timestamp', columns=['variable', 'attribute'], values='value')
print(tmp.shape)
df.index = pd.to_datetime(df.index)
final = tmp.reset_index().melt(id_vars='timestamp')
final.shape
# Out:
# (12961, 400)
# (5184400, 4)

# %%
# %%writefile utils.py
import pandas as pd
import os

def read_csv(filename):
    df = pd.read_csv(filename, skiprows=8)
    df.rename(columns={'# timestamp': 'timestamp'}, inplace=True)
    df = df.melt(id_vars='timestamp')
    prefix = os.path.basename(filename).replace('.csv','')
    df['attribute'] = prefix
    return df

def read_dir(filenames):
    df = pd.concat([ read_csv(x) for x in filenames ], axis=0, sort=False)  # axis = 0 for stacking
    #df.index = pd.to_datetime(df.index)
    tmp = df.pivot_table(index='timestamp', columns=['variable', 'attribute'], values='value')
    tmp.index = pd.to_datetime(tmp.index)
    final = tmp.reset_index().melt(id_vars='timestamp')
    return final
# Out:
# Overwriting utils.py
